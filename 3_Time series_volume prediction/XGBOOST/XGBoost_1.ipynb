# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb
from sklearn.metrics import mean_squared_error
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %%
#pip install xgboost

# %%
df = pd.read_csv('incoming_daily_till2023may_interpolated.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881 entries, 0 to 880
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    881 non-null    object
#  1   volume  881 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 13.9+ KB

# %%
# Assuming 'timestamp' is the column containing the irregular timestamps and 'value' is the column containing the volume data
df['date'] = pd.to_datetime(df['date'],format="%Y/%m/%d")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881 entries, 0 to 880
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    881 non-null    datetime64[ns]
#  1   volume  881 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 13.9 KB

# %%
df = df.set_index('date')
df.index = pd.to_datetime(df.index)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 881 entries, 2021-01-01 to 2023-05-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   volume  881 non-null    float64
# dtypes: float64(1)
# memory usage: 13.8 KB

# %%
df.plot(style='.',
        figsize=(15, 5),
        color=color_pal[0],
        title='Volume in cbm')
plt.show()

# %%
#plt.subplot(111)   #no of rows on y-axis,, 
df['volume'].plot(figsize=(16, 6), legend=True)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2, random_state=7, shuffle=False)
train.columns = df.columns
test.columns = df.columns
print(f"{train.shape[0]} train and {test.shape[0]} test instances")
# Out:
# 704 train and 177 test instances

# %%
fig, ax = plt.subplots(figsize=(15, 5))
train.plot(ax=ax, label='Training Set', title='Data Train/Test Split')
test.plot(ax=ax, label='Test Set')
ax.axvline('12-05-2022', color='black', ls='--')
ax.legend(['Training Set', 'Test Set'])
plt.show()

#5th dec 2022

# %%
df.loc[(df.index > '01-07-2021') & (df.index < '01-14-2021')] \
    .plot(figsize=(15, 5), title='Week Of Data')
plt.show()

# %%
def create_features(df):
    """
    Create time series features based on time series index.
    """
    df = df.copy()
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week
    return df

df = create_features(df)

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='dayofweek', y='volume')
ax.set_title('volume by week')
plt.show()   #monday 0--sunday 6

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='month', y='volume', palette='Blues')
ax.set_title('volume by Month')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='quarter', y='volume', palette='Blues')
ax.set_title('volume by quarter')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='year', y='volume', palette='Blues')
ax.set_title('volume by year')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='dayofyear', y='volume', palette='Blues')
ax.set_title('volume by dayofyear')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='dayofmonth', y='volume', palette='Blues')
ax.set_title('volume by dayofmonth')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='weekofyear', y='volume', palette='Blues')
ax.set_title('volume by weekofyear')
plt.show()

# %%
train = create_features(train)
test = create_features(test)

FEATURES = ['dayofweek', 'quarter', 'month', 'year']
TARGET = 'volume'

X_train = train[FEATURES]
y_train = train[TARGET]

X_test = test[FEATURES]
y_test = test[TARGET]

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=1000,
                       early_stopping_rounds=50,   #stop the model training early if the test set is not improving after 50 trees
                       objective='reg:linear',
                       max_depth=3,
                       learning_rate=0.01) #so that it doesn't overfit the model
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100) #give output of trees based on interval of 100
# Out:
# [19:47:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:691.15661	validation_1-rmse:1131.91681
# [100]	validation_0-rmse:310.61149	validation_1-rmse:724.34211
# [200]	validation_0-rmse:201.33577	validation_1-rmse:602.41793
# [300]	validation_0-rmse:176.49152	validation_1-rmse:563.15682
# [400]	validation_0-rmse:169.01401	validation_1-rmse:551.09679
# [476]	validation_0-rmse:166.86231	validation_1-rmse:549.43882
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              objective='reg:linear', predictor=None, ...)

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=1000,
                       early_stopping_rounds=50,   #stop the model training early if the test set is not improving after 50 trees
                       objective='reg:linear',
                       max_depth=3,
                    ) #so that it doesn't overfit the model
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        ) #give output of trees based on interval of 100
# Out:
# [19:47:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:509.12614	validation_1-rmse:936.37448
# [1]	validation_0-rmse:382.54938	validation_1-rmse:798.59192
# [2]	validation_0-rmse:301.15252	validation_1-rmse:706.60242
# [3]	validation_0-rmse:248.77446	validation_1-rmse:663.92202
# [4]	validation_0-rmse:214.19022	validation_1-rmse:622.99898
# [5]	validation_0-rmse:195.32951	validation_1-rmse:592.07890
# [6]	validation_0-rmse:184.35411	validation_1-rmse:579.83566
# [7]	validation_0-rmse:177.28112	validation_1-rmse:569.51314
# [8]	validation_0-rmse:173.25797	validation_1-rmse:562.40585
# [9]	validation_0-rmse:170.88286	validation_1-rmse:554.46267
# [10]	validation_0-rmse:169.19899	validation_1-rmse:554.18990
# [11]	validation_0-rmse:168.10538	validation_1-rmse:549.05743
# [12]	validation_0-rmse:167.12316	validation_1-rmse:547.43977
# [13]	validation_0-rmse:166.42517	validation_1-rmse:546.33816
# [14]	validation_0-rmse:165.86712	validation_1-rmse:547.18486
# [15]	validation_0-rmse:165.27113	validation_1-rmse:549.48351
# [16]	validation_0-rmse:164.63540	validation_1-rmse:548.98837
# [17]	validation_0-rmse:164.36034	validation_1-rmse:551.28693
# [18]	validation_0-rmse:164.08664	validation_1-rmse:549.67084
# [19]	validation_0-rmse:163.93080	validation_1-rmse:551.25361
# [20]	validation_0-rmse:163.47024	validation_1-rmse:551.83979
# [21]	validation_0-rmse:163.31088	validation_1-rmse:551.74361
# [22]	validation_0-rmse:163.16356	validation_1-rmse:552.08595
# [23]	validation_0-rmse:162.91052	validation_1-rmse:550.90572
# [24]	validation_0-rmse:162.77935	validation_1-rmse:551.51885
# [25]	validation_0-rmse:162.22990	validation_1-rmse:548.30171
# [26]	validation_0-rmse:162.08600	validation_1-rmse:548.58598
# [27]	validation_0-rmse:161.78509	validation_1-rmse:545.33273
# [28]	validation_0-rmse:161.64570	validation_1-rmse:545.18561
# [29]	validation_0-rmse:161.45196	validation_1-rmse:545.06942
# [30]	validation_0-rmse:161.38526	validation_1-rmse:545.44765
# [31]	validation_0-rmse:161.25805	validation_1-rmse:545.00184
# [32]	validation_0-rmse:161.13872	validation_1-rmse:544.86822
# [33]	validation_0-rmse:161.05453	validation_1-rmse:544.50399
# [34]	validation_0-rmse:160.94007	validation_1-rmse:544.90214
# [35]	validation_0-rmse:160.73936	validation_1-rmse:544.46708
# [36]	validation_0-rmse:160.70108	validation_1-rmse:544.67382
# [37]	validation_0-rmse:160.62030	validation_1-rmse:544.64314
# [38]	validation_0-rmse:160.55622	validation_1-rmse:544.40517
# [39]	validation_0-rmse:160.35779	validation_1-rmse:544.42192
# [40]	validation_0-rmse:160.28386	validation_1-rmse:545.77887
# [41]	validation_0-rmse:160.12333	validation_1-rmse:546.67454
# [42]	validation_0-rmse:159.94684	validation_1-rmse:544.34965
# [43]	validation_0-rmse:159.89459	validation_1-rmse:544.02292
# [44]	validation_0-rmse:159.64775	validation_1-rmse:543.83096
# [45]	validation_0-rmse:159.49976	validation_1-rmse:543.74405
# [46]	validation_0-rmse:159.44784	validation_1-rmse:544.64984
# [47]	validation_0-rmse:159.40113	validation_1-rmse:544.46392
# [48]	validation_0-rmse:159.35342	validation_1-rmse:544.75501
# [49]	validation_0-rmse:159.31232	validation_1-rmse:544.19406
# [50]	validation_0-rmse:159.25230	validation_1-rmse:543.50856
# [51]	validation_0-rmse:159.21220	validation_1-rmse:544.44099
# [52]	validation_0-rmse:158.98047	validation_1-rmse:544.58904
# [53]	validation_0-rmse:158.94420	validation_1-rmse:543.97481
# [54]	validation_0-rmse:158.71539	validation_1-rmse:543.08083
# [55]	validation_0-rmse:158.60180	validation_1-rmse:542.24463
# [56]	validation_0-rmse:158.50720	validation_1-rmse:541.89112
# [57]	validation_0-rmse:158.42695	validation_1-rmse:541.70101
# [58]	validation_0-rmse:158.38935	validation_1-rmse:542.46756
# [59]	validation_0-rmse:158.26411	validation_1-rmse:542.65862
# [60]	validation_0-rmse:158.19451	validation_1-rmse:543.15346
# [61]	validation_0-rmse:158.04719	validation_1-rmse:542.83249
# [62]	validation_0-rmse:157.98766	validation_1-rmse:542.86109
# [63]	validation_0-rmse:157.96307	validation_1-rmse:542.93818
# [64]	validation_0-rmse:157.91557	validation_1-rmse:542.53311
# [65]	validation_0-rmse:157.89028	validation_1-rmse:542.22253
# [66]	validation_0-rmse:157.84251	validation_1-rmse:542.23597
# [67]	validation_0-rmse:157.79989	validation_1-rmse:542.33319
# [68]	validation_0-rmse:157.74764	validation_1-rmse:542.36413
# [69]	validation_0-rmse:157.70797	validation_1-rmse:542.30723
# [70]	validation_0-rmse:157.61761	validation_1-rmse:542.21459
# [71]	validation_0-rmse:157.51756	validation_1-rmse:542.02370
# [72]	validation_0-rmse:157.43940	validation_1-rmse:542.09706
# [73]	validation_0-rmse:157.38906	validation_1-rmse:541.55696
# [74]	validation_0-rmse:157.28335	validation_1-rmse:541.50280
# [75]	validation_0-rmse:157.22736	validation_1-rmse:541.47937
# [76]	validation_0-rmse:157.20909	validation_1-rmse:541.39063
# [77]	validation_0-rmse:157.19485	validation_1-rmse:541.45117
# [78]	validation_0-rmse:157.18076	validation_1-rmse:541.72206
# [79]	validation_0-rmse:157.04874	validation_1-rmse:541.57570
# [80]	validation_0-rmse:157.00652	validation_1-rmse:541.45320
# [81]	validation_0-rmse:156.98774	validation_1-rmse:541.33247
# [82]	validation_0-rmse:156.94823	validation_1-rmse:541.78531
# [83]	validation_0-rmse:156.87881	validation_1-rmse:541.45804
# [84]	validation_0-rmse:156.86440	validation_1-rmse:541.74744
# [85]	validation_0-rmse:156.84079	validation_1-rmse:541.69904
# [86]	validation_0-rmse:156.79348	validation_1-rmse:541.63657
# [87]	validation_0-rmse:156.77171	validation_1-rmse:541.66112
# [88]	validation_0-rmse:156.76097	validation_1-rmse:541.67208
# [89]	validation_0-rmse:156.70188	validation_1-rmse:541.39274
# [90]	validation_0-rmse:156.66297	validation_1-rmse:542.07874
# [91]	validation_0-rmse:156.61663	validation_1-rmse:542.10433
# [92]	validation_0-rmse:156.57551	validation_1-rmse:541.93504
# [93]	validation_0-rmse:156.54239	validation_1-rmse:541.71383
# [94]	validation_0-rmse:156.52404	validation_1-rmse:541.60403
# [95]	validation_0-rmse:156.49994	validation_1-rmse:541.63162
# [96]	validation_0-rmse:156.44246	validation_1-rmse:541.50395
# [97]	validation_0-rmse:156.41675	validation_1-rmse:541.65767
# [98]	validation_0-rmse:156.38646	validation_1-rmse:541.73640
# [99]	validation_0-rmse:156.31563	validation_1-rmse:541.76161
# [100]	validation_0-rmse:156.21213	validation_1-rmse:542.33893
# [101]	validation_0-rmse:156.15625	validation_1-rmse:542.38658
# [102]	validation_0-rmse:156.11866	validation_1-rmse:542.38451
# [103]	validation_0-rmse:156.09113	validation_1-rmse:542.40470
# [104]	validation_0-rmse:156.02693	validation_1-rmse:542.27858
# [105]	validation_0-rmse:156.00615	validation_1-rmse:542.16070
# [106]	validation_0-rmse:155.95283	validation_1-rmse:541.61000
# [107]	validation_0-rmse:155.91021	validation_1-rmse:541.39642
# [108]	validation_0-rmse:155.85994	validation_1-rmse:541.67434
# [109]	validation_0-rmse:155.83800	validation_1-rmse:541.31711
# [110]	validation_0-rmse:155.81523	validation_1-rmse:541.32961
# [111]	validation_0-rmse:155.79420	validation_1-rmse:541.62579
# [112]	validation_0-rmse:155.77624	validation_1-rmse:541.63799
# [113]	validation_0-rmse:155.75635	validation_1-rmse:541.82505
# [114]	validation_0-rmse:155.74414	validation_1-rmse:541.56562
# [115]	validation_0-rmse:155.73205	validation_1-rmse:541.70992
# [116]	validation_0-rmse:155.70022	validation_1-rmse:542.24655
# [117]	validation_0-rmse:155.66793	validation_1-rmse:542.40682
# [118]	validation_0-rmse:155.63448	validation_1-rmse:541.74457
# [119]	validation_0-rmse:155.60626	validation_1-rmse:542.39514
# [120]	validation_0-rmse:155.58030	validation_1-rmse:542.34738
# [121]	validation_0-rmse:155.55924	validation_1-rmse:542.54972
# [122]	validation_0-rmse:155.54398	validation_1-rmse:542.42352
# [123]	validation_0-rmse:155.53556	validation_1-rmse:542.32164
# [124]	validation_0-rmse:155.52377	validation_1-rmse:542.45440
# [125]	validation_0-rmse:155.46612	validation_1-rmse:542.04793
# [126]	validation_0-rmse:155.45642	validation_1-rmse:542.37341
# [127]	validation_0-rmse:155.42073	validation_1-rmse:542.30248
# [128]	validation_0-rmse:155.38307	validation_1-rmse:542.28727
# [129]	validation_0-rmse:155.36635	validation_1-rmse:541.96695
# [130]	validation_0-rmse:155.35010	validation_1-rmse:542.32768
# [131]	validation_0-rmse:155.32546	validation_1-rmse:542.07531
# [132]	validation_0-rmse:155.31452	validation_1-rmse:541.85800
# [133]	validation_0-rmse:155.29288	validation_1-rmse:541.86720
# [134]	validation_0-rmse:155.28025	validation_1-rmse:542.24461
# [135]	validation_0-rmse:155.25347	validation_1-rmse:542.24998
# [136]	validation_0-rmse:155.23581	validation_1-rmse:542.34136
# [137]	validation_0-rmse:155.22088	validation_1-rmse:542.42472
# [138]	validation_0-rmse:155.20890	validation_1-rmse:542.51679
# [139]	validation_0-rmse:155.19940	validation_1-rmse:542.11645
# [140]	validation_0-rmse:155.19356	validation_1-rmse:542.28811
# [141]	validation_0-rmse:155.17262	validation_1-rmse:541.76833
# [142]	validation_0-rmse:155.15082	validation_1-rmse:541.87707
# [143]	validation_0-rmse:155.12925	validation_1-rmse:541.63683
# [144]	validation_0-rmse:155.11389	validation_1-rmse:541.88918
# [145]	validation_0-rmse:155.10738	validation_1-rmse:541.59212
# [146]	validation_0-rmse:155.08878	validation_1-rmse:541.40233
# [147]	validation_0-rmse:155.07649	validation_1-rmse:541.56540
# [148]	validation_0-rmse:155.05772	validation_1-rmse:541.49481
# [149]	validation_0-rmse:155.04245	validation_1-rmse:541.67925
# [150]	validation_0-rmse:155.03148	validation_1-rmse:541.67254
# [151]	validation_0-rmse:155.02240	validation_1-rmse:541.73928
# [152]	validation_0-rmse:155.00954	validation_1-rmse:541.69517
# [153]	validation_0-rmse:154.99953	validation_1-rmse:541.89201
# [154]	validation_0-rmse:154.99264	validation_1-rmse:542.04559
# [155]	validation_0-rmse:154.94020	validation_1-rmse:541.70738
# [156]	validation_0-rmse:154.92841	validation_1-rmse:541.72067
# [157]	validation_0-rmse:154.91742	validation_1-rmse:541.76746
# [158]	validation_0-rmse:154.91380	validation_1-rmse:541.83090
# [159]	validation_0-rmse:154.90738	validation_1-rmse:541.82842
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              objective='reg:linear', predictor=None, ...)

# %%
fi = pd.DataFrame(data=reg.feature_importances_,
             index=reg.feature_names_in_,
             columns=['importance'])
fi.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %%
test['prediction'] = reg.predict(X_test)
df = df.merge(test[['prediction']], how='left', left_index=True, right_index=True)
ax = df[['volume']].plot(figsize=(15, 5))
df['prediction'].plot(ax=ax, style='.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Raw Data and Prediction')
plt.show()

# %%
ax = df.loc[(df.index > '05-01-2023') & (df.index < '05-31-2023')]['volume'] \
    .plot(figsize=(15, 5), title='Week Of Data')
df.loc[(df.index > '05-01-2023') & (df.index < '05-31-2023')]['prediction'] \
    .plot(style='.')
plt.legend(['Truth Data','Prediction'])
plt.show()

# %%
score = np.sqrt(mean_squared_error(test['volume'], test['prediction']))
print(f'RMSE Score on Test set: {score:0.2f}')
# Out:
# RMSE Score on Test set: 541.32

# %%
# 4. Evaluate the Model
predicted = test['prediction']
actual = test['volume']

# Calculate RMSE
rmse = np.sqrt(((predicted - actual) ** 2).mean())
# Calculate MAE
mae = np.abs(predicted - actual).mean()
# Calculate MAPE
mape = (np.abs((actual - predicted) / actual)).mean() * 100
# Calculate Theil's U2
numerator = np.sqrt(np.sum((predicted - actual)**2) / len(actual))
denominator = np.sqrt((np.sum(actual**2) + np.sum(predicted**2)) / (2 * len(actual)))
theils_u2 = numerator / denominator

print(f"RMSE: {rmse}, MAE: {mae}, MAPE: {mape}%, Theil's U2: {theils_u2}")
# Out:
# RMSE: 541.3171132239074, MAE: 426.7139972320384, MAPE: 92.39320910646904%, Theil's U2: 0.5549812685508186

# %%
test['error'] = np.abs(test[TARGET] - test['prediction'])
test['date_test'] = test.index.date
test.groupby(['date_test'])['error'].mean().sort_values(ascending=False).head(10)   #worst predicted days
# Out:
# date_test
# 2022-12-26    1259.817139
# 2023-04-24    1221.155090
# 2023-05-03    1156.719177
# 2022-12-27    1126.068481
# 2022-12-29    1123.657349
# 2022-12-28    1122.789185
# 2023-04-26    1075.998230
# 2022-12-30    1020.333008
# 2023-02-27     994.373962
# 2023-05-22     963.797302
# Name: error, dtype: float64

# %%
test['error'] = np.abs(test[TARGET] - test['prediction'])
test['date_test'] = test.index.date
test.groupby(['date_test'])['error'].mean().sort_values(ascending=True).head(10)   #best predicted days
# Out:
# date_test
# 2022-12-31    0.170250
# 2023-04-22    3.206108
# 2023-02-04    3.420429
# 2023-03-04    5.688423
# 2023-01-15    5.892139
# 2022-12-18    6.100655
# 2023-02-25    6.579571
# 2023-04-23    7.403019
# 2023-02-12    7.526253
# 2023-03-26    7.886559
# Name: error, dtype: float64
