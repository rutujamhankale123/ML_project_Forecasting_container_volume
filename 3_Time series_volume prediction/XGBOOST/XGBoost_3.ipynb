# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb
from sklearn.metrics import mean_squared_error
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %%
#pip install xgboost

# %%
df = pd.read_csv('incoming_daily_till2023may_interpolated.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881 entries, 0 to 880
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    881 non-null    object
#  1   volume  881 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 13.9+ KB

# %%
# Assuming 'timestamp' is the column containing the irregular timestamps and 'value' is the column containing the volume data
df['date'] = pd.to_datetime(df['date'],format="%Y/%m/%d")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 881 entries, 0 to 880
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    881 non-null    datetime64[ns]
#  1   volume  881 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 13.9 KB

# %%
df = df.set_index('date')
df.index = pd.to_datetime(df.index)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 881 entries, 2021-01-01 to 2023-05-31
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   volume  881 non-null    float64
# dtypes: float64(1)
# memory usage: 13.8 KB

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.2, random_state=7, shuffle=False)
train.columns = df.columns
test.columns = df.columns
print(f"{train.shape[0]} train and {test.shape[0]} test instances")
# Out:
# 704 train and 177 test instances

# %%
def create_features(df):
    """
    Create time series features based on time series index.
    """
    df = df.copy()
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week
    return df

df = create_features(df)

# %%
train = create_features(train)
test = create_features(test)

FEATURES = ['dayofweek']
TARGET = 'volume'

X_train = train[FEATURES]
y_train = train[TARGET]

X_test = test[FEATURES]
y_test = test[TARGET]

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=1000,
                       early_stopping_rounds=50,   #stop the model training early if the test set is not improving after 50 trees
                       objective='reg:linear',
                       max_depth=3,
                       learning_rate=0.01) #so that it doesn't overfit the model
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100) #give output of trees based on interval of 100
# Out:
# [22:47:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:691.72666	validation_1-rmse:1132.79938
# [100]	validation_0-rmse:365.25602	validation_1-rmse:767.28980
# [200]	validation_0-rmse:294.52299	validation_1-rmse:644.00382
# [300]	validation_0-rmse:283.56201	validation_1-rmse:601.52545
# [400]	validation_0-rmse:282.03966	validation_1-rmse:586.38132
# [500]	validation_0-rmse:281.83202	validation_1-rmse:580.88846
# [600]	validation_0-rmse:281.80373	validation_1-rmse:578.87454
# [700]	validation_0-rmse:281.79987	validation_1-rmse:578.13339
# [800]	validation_0-rmse:281.79935	validation_1-rmse:577.86031
# [900]	validation_0-rmse:281.79928	validation_1-rmse:577.75960
# [999]	validation_0-rmse:281.79927	validation_1-rmse:577.72268
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              objective='reg:linear', predictor=None, ...)

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=1000,
                       early_stopping_rounds=50,   #stop the model training early if the test set is not improving after 50 trees
                       objective='reg:linear',
                       max_depth=3,
                    ) #so that it doesn't overfit the model
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        ) #give output of trees based on interval of 100
# Out:
# [22:47:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0fdc6d574b9c0d168-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:528.79737	validation_1-rmse:960.68938
# [1]	validation_0-rmse:421.79848	validation_1-rmse:839.30088
# [2]	validation_0-rmse:357.64067	validation_1-rmse:756.66902
# [3]	validation_0-rmse:321.39991	validation_1-rmse:700.50958
# [4]	validation_0-rmse:301.96194	validation_1-rmse:662.50221
# [5]	validation_0-rmse:291.91400	validation_1-rmse:636.42539
# [6]	validation_0-rmse:286.83089	validation_1-rmse:618.46068
# [7]	validation_0-rmse:284.28980	validation_1-rmse:606.10527
# [8]	validation_0-rmse:283.02979	validation_1-rmse:597.53857
# [9]	validation_0-rmse:282.40731	validation_1-rmse:591.55127
# [10]	validation_0-rmse:282.09925	validation_1-rmse:587.39076
# [11]	validation_0-rmse:281.94729	validation_1-rmse:584.49208
# [12]	validation_0-rmse:281.87230	validation_1-rmse:582.46333
# [13]	validation_0-rmse:281.83527	validation_1-rmse:581.04281
# [14]	validation_0-rmse:281.81702	validation_1-rmse:580.04376
# [15]	validation_0-rmse:281.80802	validation_1-rmse:579.34541
# [16]	validation_0-rmse:281.80359	validation_1-rmse:578.85540
# [17]	validation_0-rmse:281.80140	validation_1-rmse:578.51151
# [18]	validation_0-rmse:281.80032	validation_1-rmse:578.27011
# [19]	validation_0-rmse:281.79978	validation_1-rmse:578.10064
# [20]	validation_0-rmse:281.79952	validation_1-rmse:577.98166
# [21]	validation_0-rmse:281.79939	validation_1-rmse:577.89811
# [22]	validation_0-rmse:281.79933	validation_1-rmse:577.83949
# [23]	validation_0-rmse:281.79929	validation_1-rmse:577.79828
# [24]	validation_0-rmse:281.79928	validation_1-rmse:577.76934
# [25]	validation_0-rmse:281.79927	validation_1-rmse:577.74904
# [26]	validation_0-rmse:281.79927	validation_1-rmse:577.73448
# [27]	validation_0-rmse:281.79927	validation_1-rmse:577.72456
# [28]	validation_0-rmse:281.79926	validation_1-rmse:577.71735
# [29]	validation_0-rmse:281.79926	validation_1-rmse:577.71249
# [30]	validation_0-rmse:281.79926	validation_1-rmse:577.70908
# [31]	validation_0-rmse:281.79926	validation_1-rmse:577.70662
# [32]	validation_0-rmse:281.79926	validation_1-rmse:577.70489
# [33]	validation_0-rmse:281.79926	validation_1-rmse:577.70367
# [34]	validation_0-rmse:281.79926	validation_1-rmse:577.70282
# [35]	validation_0-rmse:281.79926	validation_1-rmse:577.70223
# [36]	validation_0-rmse:281.79926	validation_1-rmse:577.70180
# [37]	validation_0-rmse:281.79926	validation_1-rmse:577.70150
# [38]	validation_0-rmse:281.79926	validation_1-rmse:577.70129
# [39]	validation_0-rmse:281.79926	validation_1-rmse:577.70115
# [40]	validation_0-rmse:281.79926	validation_1-rmse:577.70104
# [41]	validation_0-rmse:281.79926	validation_1-rmse:577.70097
# [42]	validation_0-rmse:281.79926	validation_1-rmse:577.70091
# [43]	validation_0-rmse:281.79926	validation_1-rmse:577.70089
# [44]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [45]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [46]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [47]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [48]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [49]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [50]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [51]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [52]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [53]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [54]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [55]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [56]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [57]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [58]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [59]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [60]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [61]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [62]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [63]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [64]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [65]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [66]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [67]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [68]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [69]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [70]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [71]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [72]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [73]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [74]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [75]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [76]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [77]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [78]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [79]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [80]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [81]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [82]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [83]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [84]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [85]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [86]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [87]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [88]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [89]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [90]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [91]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [92]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [93]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# [94]	validation_0-rmse:281.79926	validation_1-rmse:577.70085
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=50,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=None, num_parallel_tree=None,
#              objective='reg:linear', predictor=None, ...)

# %%
fi = pd.DataFrame(data=reg.feature_importances_,
             index=reg.feature_names_in_,
             columns=['importance'])
fi.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %%
test['prediction'] = reg.predict(X_test)
df = df.merge(test[['prediction']], how='left', left_index=True, right_index=True)
ax = df[['volume']].plot(figsize=(15, 5))
df['prediction'].plot(ax=ax, style='.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Raw Data and Prediction')
plt.show()

# %%
ax = df.loc[(df.index > '05-01-2023') & (df.index < '05-31-2023')]['volume'] \
    .plot(figsize=(15, 5), title='Week Of Data')
df.loc[(df.index > '05-01-2023') & (df.index < '05-31-2023')]['prediction'] \
    .plot(style='.')
plt.legend(['Truth Data','Prediction'])
plt.show()

# %%
score = np.sqrt(mean_squared_error(test['volume'], test['prediction']))
print(f'RMSE Score on Test set: {score:0.2f}')
# Out:
# RMSE Score on Test set: 577.70

# %%
# 4. Evaluate the Model
predicted = test['prediction']
actual = test['volume']

# Calculate RMSE
rmse = np.sqrt(((predicted - actual) ** 2).mean())
# Calculate MAE
mae = np.abs(predicted - actual).mean()
# Calculate MAPE
mape = (np.abs((actual - predicted) / actual)).mean() * 100
# Calculate Theil's U2
numerator = np.sqrt(np.sum((predicted - actual)**2) / len(actual))
denominator = np.sqrt((np.sum(actual**2) + np.sum(predicted**2)) / (2 * len(actual)))
theils_u2 = numerator / denominator

print(f"RMSE: {rmse}, MAE: {mae}, MAPE: {mape}%, Theil's U2: {theils_u2}")
# Out:
# RMSE: 577.7008540719538, MAE: 460.8152632632498, MAPE: 98.02124192883075%, Theil's U2: 0.625053209844889

# %%
test['error'] = np.abs(test[TARGET] - test['prediction'])
test['date_test'] = test.index.date
test.groupby(['date_test'])['error'].mean().sort_values(ascending=False).head(10)   #worst predicted days
# Out:
# date_test
# 2023-05-03    1377.540161
# 2023-04-24    1288.204102
# 2023-04-26    1277.540161
# 2023-05-22    1177.704102
# 2023-05-05    1070.174988
# 2023-05-17     982.040161
# 2023-04-04     981.924988
# 2023-05-16     980.424988
# 2023-03-22     979.040161
# 2023-02-27     976.704102
# Name: error, dtype: float64

# %%
test['error'] = np.abs(test[TARGET] - test['prediction'])
test['date_test'] = test.index.date
test.groupby(['date_test'])['error'].mean().sort_values(ascending=True).head(10)   #best predicted days
# Out:
# date_test
# 2023-02-11     1.118057
# 2023-01-21     2.381943
# 2022-12-24     2.881943
# 2023-03-18     4.118057
# 2023-05-28     4.433098
# 2023-02-25     6.118057
# 2023-03-11     6.118057
# 2023-03-04     8.881943
# 2023-04-22     9.118057
# 2023-04-01    12.381943
# Name: error, dtype: float64
